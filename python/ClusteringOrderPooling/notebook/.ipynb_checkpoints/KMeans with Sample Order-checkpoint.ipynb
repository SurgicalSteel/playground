# %%
import pandas as pd
from sklearn.cluster import KMeans
import folium

file_url = "../dataset/sample_orders.csv"
data = pd.read_csv(file_url)
features = data[['Latitude', 'Longitude']]
print(features)

kmeans = KMeans(
    init="random",
    n_clusters=25,
    n_init=100,
    max_iter=1000,
    random_state=42
)

kmeans.fit(features)
labels = kmeans.labels_


data['Cluster'] = labels

_clusters = data.groupby('Cluster')['OrderId'].count()
print(_clusters)

colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', \
     'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', \
     'darkpurple', 'pink', 'lightblue', 'lightgreen', 'gray', \
     'black', 'lightgray', 'red', 'blue', 'green', 'purple', \
     'orange', 'darkred', 'lightred', 'beige', 'darkblue', \
     'darkgreen', 'cadetblue', 'darkpurple','pink', 'lightblue', \
     'lightgreen', 'gray', 'black', 'lightgray' ]

# location super KBN
lat = -6.1844292 #data.iloc[0]['Latitude']
lng =  106.7314267 # data.iloc[0]['Longitude']

map = folium.Map(location=[lng, lat], zoom_start=9)
folium.Marker(location=[lat,lng], popup='black', icon=folium.Icon(color='black')).add_to(map)

for _, row in data.iterrows():
    folium.CircleMarker(
        location=[row["Latitude"], row["Longitude"]],
        radius=12, 
        weight=2, 
        fill=True, 
        fill_color=colors[int(row["Cluster"])],
        color=colors[int(row["Cluster"])]
    ).add_to(map)


    
map
# Out:
#      Latitude   Longitude
# 0   -6.260360  106.812883
# 1   -6.202327  106.863069
# 2   -6.115357  106.759266
# 3   -6.255183  106.840091
# 4   -6.307417  106.801766
# ..        ...         ...
# 332 -6.161973  106.836647
# 333 -6.150217  106.847539
# 334 -6.349836  106.748317
# 335 -6.291133  107.031636
# 336 -6.291524  106.620144
#
# [337 rows x 2 columns]
# Cluster
# 0     19
# 1     18
# 2      4
# 3     22
# 4     18
# 5      6
# 6     14
# 7     21
# 8     11
# 9      8
# 10    20
# 11     6
# 12     7
# 13     7
# 14    12
# 15    14
# 16    12
# 17     7
# 18    12
# 19    21
# 20    16
# 21    14
# 22    22
# 23    20
# 24     6
# Name: OrderId, dtype: int64
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
# ...
